# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import regex as re
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./IMDB Top 250 Movies.csv')
data
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         250 non-null    int64
#  1   name         250 non-null    object
#  2   year         250 non-null    int64
#  3   rating       250 non-null    float64
#  4   genre        250 non-null    object
#  5   certificate  250 non-null    object
#  6   run_time     250 non-null    object
#  7   tagline      250 non-null    object
#  8   budget       250 non-null    object
#  9   box_office   250 non-null    object
#  10  casts        250 non-null    object
#  11  directors    250 non-null    object
#  12  writers      250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %% [markdown]
# ### Splitting the run time column into hours and minutes columns;

# %%
data[['Hours', 'Minutes']] = data.run_time.str.split(' ',expand=True)

# %%
data
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
data.drop(columns='run_time', inplace=True)
data.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate                                            tagline     budget  \
# 0           R  Fear can hold you prisoner. Hope can set you f...   25000000
# 1           R                         An offer you can't refuse.    6000000
# 2       PG-13                                    Why So Serious?  185000000
# 3           R       All the power on earth can't change destiny.   13000000
# 4    Approved  Life Is In Their Hands -- Death Is On Their Mi...     350000
#
#    box_office                                              casts  \
# ...

# %% [markdown]
# ### Cleaning with regural expressions

# %%
data.budget.unique()
# Out:
# array(['25000000', '6000000', '185000000', '13000000', '350000',
#        '22000000', '94000000', '8000000', '93000000', '1200000',
#        '55000000', '63000000', '160000000', '18000000', '3000000',
#        '33000000', '125000000', '3180000', '19000000', '$3300000',
#        '70000000', '165000000', '20000000', '60000000', '11000000',
#        '102000000', '35000000', '806947', '11400000', 'RF\xa0115000000',
#        '45000000', '103000000', '90000000', '40000000', '3300000',
#        '950000', '3700000', 'Not Available', '9500000', '1500000',
#        '5000000', '1000000', '31500000', '9000000', '100000000',
#        '180000000', '2000000', '1752000', '935000', '321000000',
#        '18500000', '15000000', '1800000', '250000000', '175000000',
#        '30000000', '72000000', 'EM\xa032000000', '356000000',
#        '2400000000', '550000000', '2540800', '4500000', '200000000',
#        '32500000', '12000000', '839727', '3101000', '2479000', '10000000',
# ...

# %% [markdown]
# ### Lets replace all 'Not Available' with np.nan

# %%
data.replace('Not Available', np.nan, inplace=True)
data.dropna(inplace=True)

# %%
data.budget.unique()
# Out:
# array(['25000000', '6000000', '185000000', '13000000', '350000',
#        '22000000', '94000000', '8000000', '93000000', '1200000',
#        '55000000', '63000000', '160000000', '18000000', '3000000',
#        '33000000', '125000000', '3180000', '19000000', '$3300000',
#        '70000000', '165000000', '20000000', '60000000', '11000000',
#        '102000000', '35000000', '806947', '11400000', 'RF\xa0115000000',
#        '45000000', '103000000', '90000000', '40000000', '3300000',
#        '950000', '3700000', '9500000', '1500000', '5000000', '1000000',
#        '31500000', '9000000', '100000000', '180000000', '2000000',
#        '1752000', '935000', '321000000', '18500000', '15000000',
#        '1800000', '250000000', '175000000', '30000000', '72000000',
#        '356000000', '2400000000', '550000000', '2540800', '4500000',
#        '200000000', '32500000', '12000000', '839727', '3101000',
#        '2479000', '10000000', '2200000', '927262', '170000000', '6800000',
# ...

# %% [markdown]
# ### r'\D' for removing all symbols and r'\W' for all the letters

# %%
data.columns
# Out:
# Index(['rank', 'name', 'year', 'rating', 'genre', 'certificate', 'tagline',
#        'budget', 'box_office', 'casts', 'directors', 'writers', 'Hours',
#        'Minutes'],
#       dtype='object')

# %%
data['budget'] = data['budget'].str.replace(r'\W', "")
data
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 244   245            The Iron Giant  1999     8.1  Animation,Action,Adventure
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
data.budget.unique()
# Out:
# array(['25000000', '6000000', '185000000', '13000000', '350000',
#        '22000000', '94000000', '8000000', '93000000', '1200000',
#        '55000000', '63000000', '160000000', '18000000', '3000000',
#        '33000000', '125000000', '3180000', '19000000', '3300000',
#        '70000000', '165000000', '20000000', '60000000', '11000000',
#        '102000000', '35000000', '806947', '11400000', 'RF115000000',
#        '45000000', '103000000', '90000000', '40000000', '950000',
#        '3700000', '9500000', '1500000', '5000000', '1000000', '31500000',
#        '9000000', '100000000', '180000000', '2000000', '1752000',
#        '935000', '321000000', '18500000', '15000000', '1800000',
#        '250000000', '175000000', '30000000', '72000000', '356000000',
#        '2400000000', '550000000', '2540800', '4500000', '200000000',
#        '32500000', '12000000', '839727', '3101000', '2479000', '10000000',
#        '2200000', '927262', '170000000', '6800000', '5500000', '500000',
# ...

# %%
data['budget'] = data['budget'].str.replace(r'\D', "")
data
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 244   245            The Iron Giant  1999     8.1  Animation,Action,Adventure
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
data.budget.unique()
# Out:
# array(['25000000', '6000000', '185000000', '13000000', '350000',
#        '22000000', '94000000', '8000000', '93000000', '1200000',
#        '55000000', '63000000', '160000000', '18000000', '3000000',
#        '33000000', '125000000', '3180000', '19000000', '3300000',
#        '70000000', '165000000', '20000000', '60000000', '11000000',
#        '102000000', '35000000', '806947', '11400000', '115000000',
#        '45000000', '103000000', '90000000', '40000000', '950000',
#        '3700000', '9500000', '1500000', '5000000', '1000000', '31500000',
#        '9000000', '100000000', '180000000', '2000000', '1752000',
#        '935000', '321000000', '18500000', '15000000', '1800000',
#        '250000000', '175000000', '30000000', '72000000', '356000000',
#        '2400000000', '550000000', '2540800', '4500000', '200000000',
#        '32500000', '12000000', '839727', '3101000', '2479000', '10000000',
#        '2200000', '927262', '170000000', '6800000', '5500000', '500000',
# ...
