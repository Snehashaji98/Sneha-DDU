# %%
data=pd.read_csv('./possum.csv')

# %%
data
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [104 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      104 non-null    int64
#  1   site      104 non-null    int64
#  2   Pop       104 non-null    object
#  3   sex       104 non-null    object
#  4   age       102 non-null    float64
#  5   hdlngth   104 non-null    float64
#  6   skullw    104 non-null    float64
#  7   totlngth  104 non-null    float64
#  8   taill     104 non-null    float64
#  9   footlgth  103 non-null    float64
#  10  earconch  104 non-null    float64
#  11  eye       104 non-null    float64
#  12  chest     104 non-null    float64
#  13  belly     104 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 11.5+ KB

# %%
data.shape
# Out:
# (104, 14)

# %%
data.describe().T
# Out:
#           count       mean        std   min     25%    50%     75%    max
# case      104.0  52.500000  30.166206   1.0  26.750  52.50  78.250  104.0
# site      104.0   3.625000   2.349086   1.0   1.000   3.00   6.000    7.0
# age       102.0   3.833333   1.909244   1.0   2.250   3.00   5.000    9.0
# hdlngth   104.0  92.602885   3.573349  82.5  90.675  92.80  94.725  103.1
# skullw    104.0  56.883654   3.113426  50.0  54.975  56.35  58.100   68.6
# totlngth  104.0  87.088462   4.310549  75.0  84.000  88.00  90.000   96.5
# taill     104.0  37.009615   1.959518  32.0  35.875  37.00  38.000   43.0
# footlgth  103.0  68.459223   4.395306  60.3  64.600  68.00  72.500   77.9
# earconch  104.0  48.130769   4.109380  40.3  44.800  46.80  52.000   56.2
# eye       104.0  15.046154   1.050374  12.8  14.400  14.90  15.725   17.8
# chest     104.0  27.000000   2.045597  22.0  25.500  27.00  28.000   32.0
# belly     104.0  32.586538   2.761949  25.0  31.000  32.50  34.125   40.0

# %%
data.isnull().mean()*100
# Out:
# case        0.000000
# site        0.000000
# Pop         0.000000
# sex         0.000000
# age         1.923077
# hdlngth     0.000000
# skullw      0.000000
# totlngth    0.000000
# taill       0.000000
# footlgth    0.961538
# earconch    0.000000
# eye         0.000000
# chest       0.000000
# belly       0.000000
# dtype: float64

# %% [markdown]
# ### Filling the null values

# %%
data.age.fillna(data.age.mean(),inplace=True)
data.footlgth.fillna(data.age.mean(),inplace=True)
data
# Out:
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101   102     7  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102   103     7  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103   104     7  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [104 rows x 14 columns]

# %%
data.isnull().mean()*100
# Out:
# case        0.0
# site        0.0
# Pop         0.0
# sex         0.0
# age         0.0
# hdlngth     0.0
# skullw      0.0
# totlngth    0.0
# taill       0.0
# footlgth    0.0
# earconch    0.0
# eye         0.0
# chest       0.0
# belly       0.0
# dtype: float64

# %% [markdown]
# ### Univariate analysis

# %%
for i in data.columns:
    if data[i].dtypes !="object":
        sns.histplot(x =data[i] )
        plt.show()

# %%
for i in data.columns:
    if data[i].dtypes !="object":
        sns.kdeplot(x =data[i])
        plt.show()

# %%
for i in data.columns:
    if data[i].dtypes !="object":
        sns.distplot(x =data[i])
        plt.show()

# %%
for i in data.columns:
    if data[i].dtypes !="object":
        sns.boxplot(y=data[i])
        plt.show()

# %%
for i in data.columns:
    if data[i].dtypes !="object":
        sns.boxenplot(y=data[i])
        plt.show()

# %% [markdown]
# ### Setting the outlier limits

# %%
def outlier_limit(col):
    Q3,Q1=np.nanpercentile(col,[75,25])
    IQR=Q3-Q1
    UL=Q3+1.5*IQR
    LL=Q1-1.5*IQR
    return UL,LL

# %%
for i in data.columns:
    if data[i].dtypes !="object":
        UL,LL= outlier_limit(data[i])
        data[i]=np.where((data[i]>UL)|(data[i]<LL),np.nan,data[i])

# %%
for i in data.columns:
    if data[i].dtypes !="object":
        sns.boxplot(y=data[i],color="green")
        plt.show()

# %%
data.dropna(inplace=True)
data
# Out:
#       case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0      1.0   1.0    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1      2.0   1.0    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2      3.0   1.0    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3      4.0   1.0    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4      5.0   1.0    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..     ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99   100.0   7.0  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100  101.0   7.0  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# 101  102.0   7.0  other   f  6.0     92.4    55.0      89.0   38.0      63.5
# 102  103.0   7.0  other   m  4.0     91.5    55.2      82.5   36.5      62.9
# 103  104.0   7.0  other   f  3.0     93.6    59.9      89.0   40.0      67.6
#
#      earconch   eye  chest  belly
# 0        54.5  15.2   28.0   36.0
# 1        51.2  16.0   28.5   33.0
# 2        51.9  15.5   30.0   34.0
# 3        52.2  15.2   28.0   34.0
# 4        53.2  15.1   28.5   33.0
# ..        ...   ...    ...    ...
# 99       46.8  14.8   23.0   27.0
# 100      48.0  14.0   25.0   33.0
# 101      45.4  13.0   25.0   30.0
# 102      45.9  15.4   25.0   29.0
# 103      46.0  14.8   28.5   33.5
#
# [85 rows x 14 columns]

# %% [markdown]
# ### Label encoding the categorical columns

# %%
le=LabelEncoder()
data['Pop']=le.fit_transform(data['Pop'])
data['sex']=le.fit_transform(data['sex'])

# %% [markdown]
# ### Checking the correlation with the target 'footlgth'

# %%
sns.heatmap(data.corr()[["footlgth"]].sort_values(by="footlgth",ascending=False),vmin=-1,vmax=1,annot=True,cmap="GnBu")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Lets take only the column with good correlation with the target

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 0 to 103
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   case      85 non-null     float64
#  1   site      85 non-null     float64
#  2   Pop       85 non-null     int32
#  3   sex       85 non-null     int32
#  4   age       85 non-null     float64
#  5   hdlngth   85 non-null     float64
#  6   skullw    85 non-null     float64
#  7   totlngth  85 non-null     float64
#  8   taill     85 non-null     float64
#  9   footlgth  85 non-null     float64
#  10  earconch  85 non-null     float64
#  11  eye       85 non-null     float64
#  12  chest     85 non-null     float64
#  13  belly     85 non-null     float64
# dtypes: float64(12), int32(2)
# memory usage: 9.3 KB

# %%
x=data[['hdlngth','skullw','totlngth','earconch','chest','belly']].values

# %%
y=data[['footlgth']].values

# %% [markdown]
# ## Feature Scaling

# %%
sc= StandardScaler()

# %%
x=sc.fit_transform(x)

# %% [markdown]
# ## Splitting the data into training and testing set

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### Model building

# %%
model={
    "LinearRegression":LinearRegression(),
    "Ridge":Ridge(),
    "LinearSVR":LinearSVR(),
    'Lasso':Lasso(),
    'GradientBoostingRegressor':GradientBoostingRegressor(),
    "BaggingRegressor":BaggingRegressor(),
    'ExtraTreesRegressor':ExtraTreesRegressor(),
    'HistGradientBoostingRegressor':HistGradientBoostingRegressor(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "AdaBoostRegressor":AdaBoostRegressor(),
    "RandomForestRegressor":RandomForestRegressor(random_state=0)
}

# %%
for name, model in model.items():
    model.fit(x_train,y_train)
    print("model trained with {}".format(name))
    training_score=model.score(x_train,y_train)*100
    testing_score=model.score(x_test,y_test)*100
    score=r2_score(y_test,model.predict(x_test))*100
    mae=mean_absolute_error(y_test,model.predict(x_test))
    mse=mean_squared_error(y_test,model.predict(x_test))
    rmse=np.sqrt(mse)
    print("r2score:",score)
    print("training_score:",training_score)
    print("testing_score",testing_score)
    print("mae:",mae)
    print("mse:",mse)
    print("rmse_test:",rmse)
    print("*"*100)
# Out:
# model trained with LinearRegression
# r2score: 55.21020512134132
# training_score: 82.64593977959485
# testing_score 55.21020512134132
# mae: 2.178384994038531
# mse: 7.200649196596326
# rmse_test: 2.6834025409163504
# ****************************************************************************************************
# model trained with Ridge
# r2score: 56.54126677236766
# training_score: 82.62398767703276
# testing_score 56.54126677236766
# mae: 2.1533463805953805
# mse: 6.986660540607866
# rmse_test: 2.643229188059156
# ****************************************************************************************************
# model trained with LinearSVR
# r2score: -243.7531968400604
# training_score: -75.221942652635
# testing_score -243.7531968400604
# mae: 6.445501685621613
# mse: 55.263619477596635
# rmse_test: 7.433950462412071
# ****************************************************************************************************
# model trained with Lasso
# r2score: 60.79221633944664
# training_score: 73.0822759570848
# testing_score 60.79221633944664
# mae: 2.076108612908897
# mse: 6.303254941902089
# rmse_test: 2.5106283958208726
# ****************************************************************************************************
# model trained with GradientBoostingRegressor
# r2score: 60.56942918745133
# training_score: 99.79094329320512
# testing_score 60.56942918745133
# mae: 1.9712123816671285
# mse: 6.3390714070449405
# rmse_test: 2.517751259962934
# ****************************************************************************************************
# model trained with BaggingRegressor
# r2score: 65.78247440875407
# training_score: 97.14987617092868
# testing_score 65.78247440875407
# mae: 1.9735294117647049
# mse: 5.500994117647047
# rmse_test: 2.3454198169298066
# ****************************************************************************************************
# model trained with ExtraTreesRegressor
# r2score: 71.76836485067125
# training_score: 99.99999862237064
# testing_score 71.76836485067125
# mae: 1.7306470588235332
# mse: 4.53867005882351
# rmse_test: 2.130415466246786
# ****************************************************************************************************
# model trained with HistGradientBoostingRegressor
# r2score: 76.59486044866392
# training_score: 91.48642313461026
# testing_score 76.59486044866392
# mae: 1.6414026376641289
# mse: 3.7627365734343816
# rmse_test: 1.9397774546154467
# ****************************************************************************************************
# model trained with DecisionTreeRegressor
# r2score: 70.77583015505414
# training_score: 100.0
# testing_score 70.77583015505414
# mae: 1.7235294117647066
# mse: 4.698235294117649
# rmse_test: 2.1675413015944236
# ****************************************************************************************************
# model trained with AdaBoostRegressor
# r2score: 63.96636601782695
# training_score: 94.4367619279488
# testing_score 63.96636601782695
# mae: 2.0201502128377085
# mse: 5.792961505787336
# rmse_test: 2.4068571843354842
# ****************************************************************************************************
# model trained with RandomForestRegressor
# r2score: 67.1401645028538
# training_score: 97.61416390277903
# testing_score 67.1401645028538
# mae: 1.8760588235294184
# mse: 5.2827245294118
# rmse_test: 2.298417831772935
# ****************************************************************************************************
