# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the datasets contained in the seaborn library
# ### we can get names of the datasets in the library

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1=sns.load_dataset('flights')
df1
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# 5    1949   Jun         135
# 6    1949   Jul         148
# 7    1949   Aug         148
# 8    1949   Sep         136
# 9    1949   Oct         119
# 10   1949   Nov         104
# 11   1949   Dec         118
# 12   1950   Jan         115
# 13   1950   Feb         126
# 14   1950   Mar         141
# 15   1950   Apr         135
# 16   1950   May         125
# 17   1950   Jun         149
# 18   1950   Jul         170
# 19   1950   Aug         170
# 20   1950   Sep         158
# 21   1950   Oct         133
# 22   1950   Nov         114
# 23   1950   Dec         140
# 24   1951   Jan         145
# 25   1951   Feb         150
# 26   1951   Mar         178
# 27   1951   Apr         163
# 28   1951   May         172
# 29   1951   Jun         178
# 30   1951   Jul         199
# 31   1951   Aug         199
# ...

# %% [markdown]
# ## Task:
# ### Load all the datasets and do the EDA
#
# ## 2. Scikit-learn datasets

# %%
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# ## Load data (will download the data if its the first time loading)

# %%
housing=fetch_california_housing(as_frame=True)

# %% [markdown]
# ### Create  a dataframe

# %%
df=housing['data'].join(housing['target'])
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %% [markdown]
# ### Task : Load other datasets and do the EDA
#
# ## 3.pydataset
#
# #### You may need to pip install the pydataset library

# %%
from pydataset import data

# %%
data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
data().iloc[200]
# Out:
# dataset_id                  Florida
# title         Florida County Voting
# Name: 200, dtype: object

# %%
df2=data('Florida')
df2
# Out:
#                 GORE    BUSH  BUCHANAN  NADER  BROWNE  HAGELIN  HARRIS  \
# ALACHUA        47300   34062       262   3215     658       42       4
# BAKER           2392    5610        73     53      17        3       0
# BAY            18850   38637       248    828     171       18       5
# BRADFORD        3072    5413        65     84      28        2       0
# BREVARD        97318  115185       570   4470     643       39      11
# BROWARD       386518  177279       789   7099    1212      128      49
# CALHOUN         2155    2873        90     39      10        1       0
# CHARLOTTE      29641   35419       182   1461     127       15       6
# CITRUS         25501   29744       270   1378     194       16       5
# CLAY           14630   41745       186    562     204       14       1
# COLLIER        29905   60426       122   1400     185       34       7
# COLUMBIA        7047   10964        89    258     127        7       1
# ...

# %%
data().iloc[1]
# Out:
# dataset_id                              BJsales
# title         Sales Data with Leading Indicator
# Name: 1, dtype: object

# %% [markdown]
# ### These are the names of data sets available,There are currently 757 Dtasets.
#
# ## Loading the BOD dataset

# %%
df=data('BOD')
df
# Out:
#    Time  demand
# 1     1     8.3
# 2     2    10.3
# 3     3    19.0
# 4     4    16.0
# 5     5    15.6
# 6     7    19.8

# %% [markdown]
# ### Task:
#     Load other datasets and do the EDA

# %%
df1=data('HairEyeColor')
df1
# Out:
#      Hair    Eye     Sex  Freq
# 1   Black  Brown    Male    32
# 2   Brown  Brown    Male    53
# 3     Red  Brown    Male    10
# 4   Blond  Brown    Male     3
# 5   Black   Blue    Male    11
# 6   Brown   Blue    Male    50
# 7     Red   Blue    Male    10
# 8   Blond   Blue    Male    30
# 9   Black  Hazel    Male    10
# 10  Brown  Hazel    Male    25
# 11    Red  Hazel    Male     7
# 12  Blond  Hazel    Male     5
# 13  Black  Green    Male     3
# 14  Brown  Green    Male    15
# 15    Red  Green    Male     7
# 16  Blond  Green    Male     8
# 17  Black  Brown  Female    36
# 18  Brown  Brown  Female    66
# 19    Red  Brown  Female    16
# 20  Blond  Brown  Female     4
# 21  Black   Blue  Female     9
# 22  Brown   Blue  Female    34
# 23    Red   Blue  Female     7
# 24  Blond   Blue  Female    64
# 25  Black  Hazel  Female     5
# 26  Brown  Hazel  Female    29
# 27    Red  Hazel  Female     7
# 28  Blond  Hazel  Female     5
# 29  Black  Green  Female     2
# ...
